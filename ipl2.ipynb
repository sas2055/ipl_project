# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('matches.csv')
df
# Out:
#         id    Season           city        date                        team1  \
# 0        1  IPL-2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1        2  IPL-2017           Pune  06-04-2017               Mumbai Indians
# 2        3  IPL-2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4  IPL-2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5  IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..     ...       ...            ...         ...                          ...
# 751  11347  IPL-2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %%
df.columns
# Out:
# Index(['id', 'Season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
df['year'] = df.Season.str.split('-',expand=True)[1]

# %%
df.columns
# Out:
# Index(['id', 'Season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3', 'year'],
#       dtype='object')

# %%
# Save changed dataframe as a file
df.to_csv('ipl_m.csv',index=False)

# %%
# Now read a new file 
a = pd.read_csv('ipl_m.csv')
a
# Out:
#         id    Season           city        date                        team1  \
# 0        1  IPL-2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1        2  IPL-2017           Pune  06-04-2017               Mumbai Indians
# 2        3  IPL-2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4  IPL-2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5  IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..     ...       ...            ...         ...                          ...
# 751  11347  IPL-2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %%
a[:2]
# Out:
#    id    Season       city        date                team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017  Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017       Mumbai Indians
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
#
#    result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# 0  normal           0     Sunrisers Hyderabad           35               0
# 1  normal           0  Rising Pune Supergiant            0               7
#
#   player_of_match                                      venue         umpire1  \
# 0    Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal     AY Dandekar
# 1       SPD Smith    Maharashtra Cricket Association Stadium  A Nand Kishore
#
#     umpire2 umpire3  year
# 0  NJ Llong     NaN  2017
# 1    S Ravi     NaN  2017

# %% [markdown]
# ### Remove id and Season column

# %%
a.drop(columns=['id','Season']) # temp change
# Out:
#               city        date                        team1  \
# 0        Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1             Pune  06-04-2017               Mumbai Indians
# 2           Rajkot  07-04-2017                Gujarat Lions
# 3           Indore  08-04-2017       Rising Pune Supergiant
# 4        Bangalore  08-04-2017  Royal Challengers Bangalore
# ..             ...         ...                          ...
# 751         Mumbai  05-05-2019        Kolkata Knight Riders
# 752        Chennai  07-05-2019          Chennai Super Kings
# 753  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  Visakhapatnam  10-05-2019               Delhi Capitals
# 755      Hyderabad  12-05-2019               Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1         Rising Pune Supergiant       Rising Pune Supergiant         field
# ...

# %%
a.drop(columns=['id','Season'], inplace=True)

# %%
a.columns
# Out:
# Index(['city', 'date', 'team1', 'team2', 'toss_winner', 'toss_decision',
#        'result', 'dl_applied', 'winner', 'win_by_runs', 'win_by_wickets',
#        'player_of_match', 'venue', 'umpire1', 'umpire2', 'umpire3', 'year'],
#       dtype='object')

# %%
# remove row with index 0,1,2
a.drop(index=[0,1,2])
# Out:
#               city        date                        team1  \
# 3           Indore  08-04-2017       Rising Pune Supergiant
# 4        Bangalore  08-04-2017  Royal Challengers Bangalore
# 5        Hyderabad  09-04-2017                Gujarat Lions
# 6           Mumbai  09-04-2017        Kolkata Knight Riders
# 7           Indore  10-04-2017  Royal Challengers Bangalore
# ..             ...         ...                          ...
# 751         Mumbai  05-05-2019        Kolkata Knight Riders
# 752        Chennai  07-05-2019          Chennai Super Kings
# 753  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  Visakhapatnam  10-05-2019               Delhi Capitals
# 755      Hyderabad  12-05-2019               Mumbai Indians
#
#                    team2                  toss_winner toss_decision  result  \
# 3        Kings XI Punjab              Kings XI Punjab         field  normal
# 4       Delhi Daredevils  Royal Challengers Bangalore           bat  normal
# ...

# %%
# Delete rows of 2017
# remove record of year 2017
# first check unique years
a.year.unique()
# not preserving sorted order
# Out:
# array([2017, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2018,
#        2019], dtype=int64)

# %%
np.unique(a.year) # preserving sorted order
# Out:
# array([2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018,
#        2019], dtype=int64)

# %%
a = a[['year','city', 'date', 'team1', 'team2', 'toss_winner', 'toss_decision',
       'result', 'dl_applied', 'winner', 'win_by_runs', 'win_by_wickets',
       'player_of_match', 'venue', 'umpire1', 'umpire2', 'umpire3']]

# %%
a
# Out:
#      year           city        date                        team1  \
# 0    2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1    2017           Pune  06-04-2017               Mumbai Indians
# 2    2017         Rajkot  07-04-2017                Gujarat Lions
# 3    2017         Indore  08-04-2017       Rising Pune Supergiant
# 4    2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..    ...            ...         ...                          ...
# 751  2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  2019        Chennai  07-05-2019          Chennai Super Kings
# 753  2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  2019      Hyderabad  12-05-2019               Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
a[:2]
# Out:
#    year       city        date                team1  \
# 0  2017  Hyderabad  05-04-2017  Sunrisers Hyderabad
# 1  2017       Pune  06-04-2017       Mumbai Indians
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
#
#    result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# 0  normal           0     Sunrisers Hyderabad           35               0
# 1  normal           0  Rising Pune Supergiant            0               7
#
#   player_of_match                                      venue         umpire1  \
# 0    Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal     AY Dandekar
# 1       SPD Smith    Maharashtra Cricket Association Stadium  A Nand Kishore
#
#     umpire2 umpire3
# 0  NJ Llong     NaN
# 1    S Ravi     NaN

# %% [markdown]
# ### sort data on the basis of year column

# %%
a.sort_values(by='year',inplace=True)

# %%
a
# Out:
#      year        city        date                  team1  \
# 116  2008      Mumbai  01-06-2008    Chennai Super Kings
# 82   2008      Jaipur  04-05-2008    Chennai Super Kings
# 81   2008      Mumbai  04-05-2008         Mumbai Indians
# 80   2008  Chandigarh  03-05-2008        Kings XI Punjab
# 79   2008   Hyderabad  25-05-2008        Deccan Chargers
# ..    ...         ...         ...                    ...
# 721  2019     Kolkata  12-04-2019  Kolkata Knight Riders
# 722  2019      Mumbai  13-04-2019         Mumbai Indians
# 723  2019      Mohali  13-04-2019        Kings XI Punjab
# 725  2019   Hyderabad  14-04-2019         Delhi Capitals
# 755  2019   Hyderabad  12-05-2019         Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# 116             Rajasthan Royals             Rajasthan Royals         field
# 82              Rajasthan Royals          Chennai Super Kings           bat
# ...

# %% [markdown]
# #### above/current output index is not in proper order

# %%
# lets reset index
a.reset_index()
# Out:
#      index  year        city        date                  team1  \
# 0      116  2008      Mumbai  01-06-2008    Chennai Super Kings
# 1       82  2008      Jaipur  04-05-2008    Chennai Super Kings
# 2       81  2008      Mumbai  04-05-2008         Mumbai Indians
# 3       80  2008  Chandigarh  03-05-2008        Kings XI Punjab
# 4       79  2008   Hyderabad  25-05-2008        Deccan Chargers
# ..     ...   ...         ...         ...                    ...
# 751    721  2019     Kolkata  12-04-2019  Kolkata Knight Riders
# 752    722  2019      Mumbai  13-04-2019         Mumbai Indians
# 753    723  2019      Mohali  13-04-2019        Kings XI Punjab
# 754    725  2019   Hyderabad  14-04-2019         Delhi Capitals
# 755    755  2019   Hyderabad  12-05-2019         Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# 0               Rajasthan Royals             Rajasthan Royals         field
# ...

# %%
# we dont want index column
a.reset_index(drop=True,inplace=True)

# %%
a
# Out:
#      year        city        date                  team1  \
# 0    2008      Mumbai  01-06-2008    Chennai Super Kings
# 1    2008      Jaipur  04-05-2008    Chennai Super Kings
# 2    2008      Mumbai  04-05-2008         Mumbai Indians
# 3    2008  Chandigarh  03-05-2008        Kings XI Punjab
# 4    2008   Hyderabad  25-05-2008        Deccan Chargers
# ..    ...         ...         ...                    ...
# 751  2019     Kolkata  12-04-2019  Kolkata Knight Riders
# 752  2019      Mumbai  13-04-2019         Mumbai Indians
# 753  2019      Mohali  13-04-2019        Kings XI Punjab
# 754  2019   Hyderabad  14-04-2019         Delhi Capitals
# 755  2019   Hyderabad  12-05-2019         Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# 0               Rajasthan Royals             Rajasthan Royals         field
# 1               Rajasthan Royals          Chennai Super Kings           bat
# ...

# %%
a[a.year == 2017].index
# Out:
# Int64Index([577, 578, 579, 580, 581, 582, 583, 584, 585, 586, 587, 588, 589,
#             590, 591, 592, 593, 594, 595, 596, 597, 598, 599, 600, 601, 602,
#             603, 604, 605, 606, 607, 608, 609, 610, 611, 612, 613, 614, 615,
#             616, 617, 618, 619, 620, 621, 622, 623, 624, 625, 626, 627, 628,
#             629, 630, 631, 632, 633, 634, 635],
#            dtype='int64')

# %%
index_17 = a[a.year == 2017].index
index_17
# Out:
# Int64Index([577, 578, 579, 580, 581, 582, 583, 584, 585, 586, 587, 588, 589,
#             590, 591, 592, 593, 594, 595, 596, 597, 598, 599, 600, 601, 602,
#             603, 604, 605, 606, 607, 608, 609, 610, 611, 612, 613, 614, 615,
#             616, 617, 618, 619, 620, 621, 622, 623, 624, 625, 626, 627, 628,
#             629, 630, 631, 632, 633, 634, 635],
#            dtype='int64')

# %%
a_17 = a.drop(index=index_17)
a_17
# Out:
#      year        city        date                  team1  \
# 0    2008      Mumbai  01-06-2008    Chennai Super Kings
# 1    2008      Jaipur  04-05-2008    Chennai Super Kings
# 2    2008      Mumbai  04-05-2008         Mumbai Indians
# 3    2008  Chandigarh  03-05-2008        Kings XI Punjab
# 4    2008   Hyderabad  25-05-2008        Deccan Chargers
# ..    ...         ...         ...                    ...
# 751  2019     Kolkata  12-04-2019  Kolkata Knight Riders
# 752  2019      Mumbai  13-04-2019         Mumbai Indians
# 753  2019      Mohali  13-04-2019        Kings XI Punjab
# 754  2019   Hyderabad  14-04-2019         Delhi Capitals
# 755  2019   Hyderabad  12-05-2019         Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# 0               Rajasthan Royals             Rajasthan Royals         field
# 1               Rajasthan Royals          Chennai Super Kings           bat
# ...

# %%
a_17.head(2)
# Out:
#    year    city        date                team1             team2  \
# 0  2008  Mumbai  01-06-2008  Chennai Super Kings  Rajasthan Royals
# 1  2008  Jaipur  04-05-2008  Chennai Super Kings  Rajasthan Royals
#
#            toss_winner toss_decision  result  dl_applied            winner  \
# 0     Rajasthan Royals         field  normal           0  Rajasthan Royals
# 1  Chennai Super Kings           bat  normal           0  Rajasthan Royals
#
#    win_by_runs  win_by_wickets player_of_match                       venue  \
# 0            0               3       YK Pathan  Dr DY Patil Sports Academy
# 1            0               8   Sohail Tanvir      Sawai Mansingh Stadium
#
#      umpire1         umpire2 umpire3
# 0  BF Bowden     RE Koertzen     NaN
# 1  Asad Rauf  AV Jayaprakash     NaN

# %%
a_17.year.unique()
# Out:
# array([2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2018, 2019],
#       dtype=int64)

# %%
# check date column
a_17.sort_values(by='date')
# Out:
#      year         city        date                        team1  \
# 117  2010      Kolkata  01-04-2010        Kolkata Knight Riders
# 739  2019       Mohali  01-04-2019              Kings XI Punjab
# 7    2008    Hyderabad  01-05-2008              Deccan Chargers
# 6    2008       Jaipur  01-05-2008             Rajasthan Royals
# 105  2009  East London  01-05-2009               Mumbai Indians
# ..    ...          ...         ...                          ...
# 119  2010      Chennai  31-03-2010  Royal Challengers Bangalore
# 118  2010        Delhi  31-03-2010             Delhi Daredevils
# 738  2019      Chennai  31-03-2019          Chennai Super Kings
# 737  2019    Hyderabad  31-03-2019          Sunrisers Hyderabad
# 55   2008       Mumbai  31-05-2008              Kings XI Punjab
#
#                            team2                  toss_winner toss_decision  \
# 117              Deccan Chargers        Kolkata Knight Riders           bat
# ...

# %%
a_17.date.dtype
# Out:
# dtype('O')

# %%
a_17.date = pd.to_datetime(a_17.date)
a_17.date
# Out:
# C:\Users\chava\AppData\Local\Temp\ipykernel_6720\3191811856.py:1: UserWarning: Parsing '25-05-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   a_17.date = pd.to_datetime(a_17.date)
# C:\Users\chava\AppData\Local\Temp\ipykernel_6720\3191811856.py:1: UserWarning: Parsing '30-04-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   a_17.date = pd.to_datetime(a_17.date)
# C:\Users\chava\AppData\Local\Temp\ipykernel_6720\3191811856.py:1: UserWarning: Parsing '29-04-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   a_17.date = pd.to_datetime(a_17.date)
# C:\Users\chava\AppData\Local\Temp\ipykernel_6720\3191811856.py:1: UserWarning: Parsing '28-04-2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   a_17.date = pd.to_datetime(a_17.date)
# ...

# %%
a_17.sort_values(by='date')
# Out:
#      year           city       date                  team1  \
# 6    2008         Jaipur 2008-01-05       Rajasthan Royals
# 7    2008      Hyderabad 2008-01-05        Deccan Chargers
# 0    2008         Mumbai 2008-01-06    Chennai Super Kings
# 5    2008        Chennai 2008-02-05    Chennai Super Kings
# 3    2008     Chandigarh 2008-03-05        Kings XI Punjab
# ..    ...            ...        ...                    ...
# 749  2019         Mumbai 2019-10-04        Kings XI Punjab
# 709  2019  Visakhapatnam 2019-10-05         Delhi Capitals
# 750  2019         Jaipur 2019-11-04       Rajasthan Royals
# 751  2019        Kolkata 2019-12-04  Kolkata Knight Riders
# 755  2019      Hyderabad 2019-12-05         Mumbai Indians
#
#                      team2          toss_winner toss_decision  result  \
# 6    Kolkata Knight Riders     Rajasthan Royals           bat  normal
# 7          Kings XI Punjab      Kings XI Punjab         field  normal
# ...

# %%
yr = a_17[['year']]
yr
# Out:
#      year
# 0    2008
# 1    2008
# 2    2008
# 3    2008
# 4    2008
# ..    ...
# 751  2019
# 752  2019
# 753  2019
# 754  2019
# 755  2019
#
# [697 rows x 1 columns]

# %%
yr[:2]
# Out:
#    year
# 0  2008
# 1  2008

# %% [markdown]
# ### how to convert dictionary

# %%
print(dict(yr)) # output is year is key and then all values
# Out:
# {'year': 0      2008
# 1      2008
# 2      2008
# 3      2008
# 4      2008
#        ...
# 751    2019
# 752    2019
# 753    2019
# 754    2019
# 755    2019
# Name: year, Length: 697, dtype: int64}

# %%
yr.to_dict() # output is dict of dict form
# Out:
# {'year': {0: 2008,
#   1: 2008,
#   2: 2008,
#   3: 2008,
#   4: 2008,
#   5: 2008,
#   6: 2008,
#   7: 2008,
#   8: 2008,
#   9: 2008,
#   10: 2008,
#   11: 2008,
#   12: 2008,
#   13: 2008,
#   14: 2008,
#   15: 2008,
#   16: 2008,
#   17: 2008,
#   18: 2008,
#   19: 2008,
#   20: 2008,
#   21: 2008,
#   22: 2008,
#   23: 2008,
#   24: 2008,
#   25: 2008,
#   26: 2008,
#   27: 2008,
#   28: 2008,
#   29: 2008,
#   30: 2008,
#   31: 2008,
#   32: 2008,
#   33: 2008,
#   34: 2008,
#   35: 2008,
#   36: 2008,
#   37: 2008,
#   38: 2008,
#   39: 2008,
#   40: 2008,
#   41: 2008,
#   42: 2008,
#   43: 2008,
#   44: 2008,
#   45: 2008,
#   46: 2008,
#   47: 2008,
#   48: 2008,
#   49: 2008,
#   50: 2008,
#   51: 2008,
#   52: 2008,
#   53: 2008,
#   54: 2008,
#   55: 2008,
#   56: 2008,
#   57: 2008,
#   58: 2009,
#   59: 2009,
#   60: 2009,
#   61: 2009,
#   62: 2009,
#   63: 2009,
#   64: 2009,
#   65: 2009,
#   66: 2009,
#   67: 2009,
#   68: 2009,
#   69: 2009,
#   70: 2009,
# ...

# %%
yr.year.unique()
# Out:
# array([2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2018, 2019],
#       dtype=int64)

# %%
# key + values without using built in method
f = {}
f['year'] = yr.year.unique()
f
# Out:
# {'year': array([2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2018, 2019],
#        dtype=int64)}

# %% [markdown]
# ### How many matches played in season 2019

# %%
a_17[a_17.year == 2019].shape
# Out:
# (60, 17)

# %%
a_17[a_17.year == 2019].shape[0]
# Out:
# 60

# %%
sum(a_17.year == 2019)
# Out:
# 60

# %% [markdown]
# ### How many matches played at Rajiv Gandhi International Stadium, Uppal

# %%
a_17.venue.value_counts()['Rajiv Gandhi International Stadium, Uppal']
# Out:
# 48

# %%
a_17.venue.unique()
# Out:
# array(['Dr DY Patil Sports Academy', 'Sawai Mansingh Stadium',
#        'Punjab Cricket Association Stadium, Mohali',
#        'Rajiv Gandhi International Stadium, Uppal',
#        'MA Chidambaram Stadium, Chepauk', 'Feroz Shah Kotla',
#        'Eden Gardens', 'M Chinnaswamy Stadium', 'Wankhede Stadium',
#        'SuperSport Park', 'Buffalo Park', 'De Beers Diamond Oval',
#        "St George's Park", 'New Wanderers Stadium', 'Kingsmead',
#        'OUTsurance Oval', 'Newlands', 'Brabourne Stadium',
#        'Sardar Patel Stadium, Motera', 'Barabati Stadium',
#        'Himachal Pradesh Cricket Association Stadium',
#        'Vidarbha Cricket Association Stadium, Jamtha', 'Nehru Stadium',
#        'Holkar Cricket Stadium', 'Subrata Roy Sahara Stadium',
#        'Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium',
#        'Shaheed Veer Narayan Singh International Stadium',
#        'JSCA International Stadium Complex',
# ...

# %%
a_17.venue.nunique()
# Out:
# 41

# %%
sum(a_17.venue.str.startswith('Rajiv'))
# Out:
# 56

# %%
'Punjab Cricket Association IS Bindra Stadium, Mohali'.lower().find('is bindra')
# Out:
# 27

# %%
'Punjab Cricket Association IS Bindra Stadium, Mohali'.find('Feroz shah')
# Out:
# -1

# %%
a_17
# Out:
#      year        city       date                  team1  \
# 0    2008      Mumbai 2008-01-06    Chennai Super Kings
# 1    2008      Jaipur 2008-04-05    Chennai Super Kings
# 2    2008      Mumbai 2008-04-05         Mumbai Indians
# 3    2008  Chandigarh 2008-03-05        Kings XI Punjab
# 4    2008   Hyderabad 2008-05-25        Deccan Chargers
# ..    ...         ...        ...                    ...
# 751  2019     Kolkata 2019-12-04  Kolkata Knight Riders
# 752  2019      Mumbai 2019-04-13         Mumbai Indians
# 753  2019      Mohali 2019-04-13        Kings XI Punjab
# 754  2019   Hyderabad 2019-04-14         Delhi Capitals
# 755  2019   Hyderabad 2019-12-05         Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# 0               Rajasthan Royals             Rajasthan Royals         field
# 1               Rajasthan Royals          Chennai Super Kings           bat
# ...

# %%
a_17.columns
# Out:
# Index(['year', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
df
# Out:
#         id    Season           city        date                        team1  \
# 0        1  IPL-2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1        2  IPL-2017           Pune  06-04-2017               Mumbai Indians
# 2        3  IPL-2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4  IPL-2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5  IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..     ...       ...            ...         ...                          ...
# 751  11347  IPL-2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %% [markdown]
# ### how many matches playes in Season 2013

# %%
a_17[a_17.year == 2013].shape
# Out:
# (76, 17)

# %%
a_17[a_17.year == 2013].shape[0]
# Out:
# 76

# %%
sum(a_17.year == 2013)
# Out:
# 76
