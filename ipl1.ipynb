# %% [markdown]
# ## Analysis of IPL Dataset

# %% [markdown]
# #### Exploratory Data Analysis:
#         1. Exploratory data analysis is an approach to analyzing data sets to summarize their main characteristics, often with visual methods..
#     2. In data science, it is often used as a starting point to gain insights about the dataset and understanding the features of the dataset.
#     3. Data visualization is a very important part in data science as data nowadays is like oil, it increases continuosly and if it is not represented properly, valuable points/insights may be lost.

# %% [markdown]
# ### Read the file

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('matches.csv')
df
# Out:
#         id    Season           city        date                        team1  \
# 0        1  IPL-2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1        2  IPL-2017           Pune  06-04-2017               Mumbai Indians
# 2        3  IPL-2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4  IPL-2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5  IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..     ...       ...            ...         ...                          ...
# 751  11347  IPL-2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %%
df.columns
# Out:
# Index(['id', 'Season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %% [markdown]
# ### Fetch top 3 records

# %%
df.head(3)
# Out:
#    id    Season       city        date                team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017  Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017       Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017        Gujarat Lions
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
#
#    result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# 0  normal           0     Sunrisers Hyderabad           35               0
# 1  normal           0  Rising Pune Supergiant            0               7
# 2  normal           0   Kolkata Knight Riders            0              10
#
#   player_of_match                                      venue         umpire1  \
# ...

# %% [markdown]
# ### fetch last 3 records

# %%
df.tail(3)
# Out:
#         id    Season           city        date                team1  \
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019  Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019       Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019       Mumbai Indians
#
#                    team2          toss_winner toss_decision  result  \
# 753       Delhi Capitals       Delhi Capitals         field  normal
# 754  Chennai Super Kings  Chennai Super Kings         field  normal
# 755  Chennai Super Kings       Mumbai Indians           bat  normal
#
#      dl_applied               winner  win_by_runs  win_by_wickets  \
# 753           0       Delhi Capitals            0               2
# 754           0  Chennai Super Kings            0               6
# 755           0       Mumbai Indians            1               0
#
#     player_of_match                               venue        umpire1  \
# 753         RR Pant                    ACA-VDCA Stadium            NaN
# ...

# %%
df[-3:]
# Out:
#         id    Season           city        date                team1  \
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019  Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019       Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019       Mumbai Indians
#
#                    team2          toss_winner toss_decision  result  \
# 753       Delhi Capitals       Delhi Capitals         field  normal
# 754  Chennai Super Kings  Chennai Super Kings         field  normal
# 755  Chennai Super Kings       Mumbai Indians           bat  normal
#
#      dl_applied               winner  win_by_runs  win_by_wickets  \
# 753           0       Delhi Capitals            0               2
# 754           0  Chennai Super Kings            0               6
# 755           0       Mumbai Indians            1               0
#
#     player_of_match                               venue        umpire1  \
# 753         RR Pant                    ACA-VDCA Stadium            NaN
# ...

# %% [markdown]
# ### How many rows and columns present?¶

# %%
sh = df.shape
sh
# Out:
# (756, 18)

# %%
print('Total number of rows:', sh[0])
print('Total number of columns:', sh[1])
# Out:
# Total number of rows: 756
# Total number of columns: 18

# %% [markdown]
# ### List out the names of columns

# %%
df.columns
# Out:
# Index(['id', 'Season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
print(list(df.columns))
# Out:
# ['id', 'Season', 'city', 'date', 'team1', 'team2', 'toss_winner', 'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs', 'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2', 'umpire3']

# %%
np.array(df.columns)
# Out:
# array(['id', 'Season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'], dtype=object)

# %% [markdown]
# ### check the abstract summary of data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   Season           756 non-null    object
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %% [markdown]
# ### Convert some object type columns into a category type

# %%
df.Season = df.Season.astype('category')
df.Season
# Out:
# 0      IPL-2017
# 1      IPL-2017
# 2      IPL-2017
# 3      IPL-2017
# 4      IPL-2017
#          ...
# 751    IPL-2019
# 752    IPL-2019
# 753    IPL-2019
# 754    IPL-2019
# 755    IPL-2019
# Name: Season, Length: 756, dtype: category
# Categories (12, object): ['IPL-2008', 'IPL-2009', 'IPL-2010', 'IPL-2011', ..., 'IPL-2016', 'IPL-2017', 'IPL-2018', 'IPL-2019']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   Season           756 non-null    category
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %% [markdown]
# ### Delete id column

# %%
del df['id']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Season           756 non-null    category
#  1   city             749 non-null    object
#  2   date             756 non-null    object
#  3   team1            756 non-null    object
#  4   team2            756 non-null    object
#  5   toss_winner      756 non-null    object
#  6   toss_decision    756 non-null    object
#  7   result           756 non-null    object
#  8   dl_applied       756 non-null    int64
#  9   winner           752 non-null    object
#  10  win_by_runs      756 non-null    int64
#  11  win_by_wickets   756 non-null    int64
#  12  player_of_match  752 non-null    object
#  13  venue            756 non-null    object
#  14  umpire1          754 non-null    object
#  15  umpire2          754 non-null    object
# ...

# %% [markdown]
# ### check the missing values

# %%
b = pd.read_excel('Book1.xlsx')
b
# Out:
#   SEGMENT_CODE OG_DIP_CODE  count$
# 0           AC         CAN     NaN
# 1           AC         CMP  4002.0
# 2          NaN         NaN    17.0
# 3          ARB         NaN   339.0
# 4          NaN         CAN     NaN
# 5          BSD         CMP  1470.0
# 6         CHAT         CAN    18.0
# 7         CHAT         CMP     NaN

# %%
# NAN: Not a Number: when data is missing

# %%
b[:2]
# Out:
#   SEGMENT_CODE OG_DIP_CODE  count$
# 0           AC         CAN     NaN
# 1           AC         CMP  4002.0

# %%
b.isna().sum()
# Out:
# SEGMENT_CODE    2
# OG_DIP_CODE     2
# count$          3
# dtype: int64

# %%
b.isna()
# Out:
#    SEGMENT_CODE  OG_DIP_CODE  count$
# 0         False        False    True
# 1         False        False   False
# 2          True         True   False
# 3         False         True   False
# 4          True        False    True
# 5         False        False   False
# 6         False        False   False
# 7         False        False    True

# %%
df.isna()
# Out:
#      Season   city   date  team1  team2  toss_winner  toss_decision  result  \
# 0     False  False  False  False  False        False          False   False
# 1     False  False  False  False  False        False          False   False
# 2     False  False  False  False  False        False          False   False
# 3     False  False  False  False  False        False          False   False
# 4     False  False  False  False  False        False          False   False
# ..      ...    ...    ...    ...    ...          ...            ...     ...
# 751   False  False  False  False  False        False          False   False
# 752   False  False  False  False  False        False          False   False
# 753   False  False  False  False  False        False          False   False
# 754   False  False  False  False  False        False          False   False
# 755   False  False  False  False  False        False          False   False
#
# ...

# %%
df.isna().sum()
# Out:
# Season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %% [markdown]
# ### check %wise missing data

# %%
miss = df.isna().sum()
# select a column with mmissing values>200
miss[miss>200].plot(kind='pie', autopct='%.f%%')
# Out:
# <AxesSubplot:ylabel='None'>

# %%
miss.plot(kind='pie',autopct='%.f%%')
# Out:
# <AxesSubplot:ylabel='None'>

# %%
m = pd.DataFrame(miss)
sns.heatmap(m,cmap='rainbow')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### check descriptive statistics

# %%
df.describe()
# Out:
#        dl_applied  win_by_runs  win_by_wickets
# count  756.000000   756.000000      756.000000
# mean     0.025132    13.283069        3.350529
# std      0.156630    23.471144        3.387963
# min      0.000000     0.000000        0.000000
# 25%      0.000000     0.000000        0.000000
# 50%      0.000000     0.000000        4.000000
# 75%      0.000000    19.000000        6.000000
# max      1.000000   146.000000       10.000000

# %% [markdown]
# ### check the data of any column

# %%
df.city
# Out:
# 0          Hyderabad
# 1               Pune
# 2             Rajkot
# 3             Indore
# 4          Bangalore
#            ...
# 751           Mumbai
# 752          Chennai
# 753    Visakhapatnam
# 754    Visakhapatnam
# 755        Hyderabad
# Name: city, Length: 756, dtype: object

# %%
df['city']
# Out:
# 0          Hyderabad
# 1               Pune
# 2             Rajkot
# 3             Indore
# 4          Bangalore
#            ...
# 751           Mumbai
# 752          Chennai
# 753    Visakhapatnam
# 754    Visakhapatnam
# 755        Hyderabad
# Name: city, Length: 756, dtype: object

# %%
b['count$']
# Out:
# 0       NaN
# 1    4002.0
# 2      17.0
# 3     339.0
# 4       NaN
# 5    1470.0
# 6      18.0
# 7       NaN
# Name: count$, dtype: float64

# %%
b.columns
# Out:
# Index(['SEGMENT_CODE', 'OG_DIP_CODE', 'count$'], dtype='object')

# %% [markdown]
# ### check data type of each column

# %%
df.dtypes
# Out:
# Season             category
# city                 object
# date                 object
# team1                object
# team2                object
# toss_winner          object
# toss_decision        object
# result               object
# dl_applied            int64
# winner               object
# win_by_runs           int64
# win_by_wickets        int64
# player_of_match      object
# venue                object
# umpire1              object
# umpire2              object
# umpire3              object
# dtype: object

# %% [markdown]
# ### Fetch City and result column

# %%
df[['city','result']]
# Out:
#               city  result
# 0        Hyderabad  normal
# 1             Pune  normal
# 2           Rajkot  normal
# 3           Indore  normal
# 4        Bangalore  normal
# ..             ...     ...
# 751         Mumbai  normal
# 752        Chennai  normal
# 753  Visakhapatnam  normal
# 754  Visakhapatnam  normal
# 755      Hyderabad  normal
#
# [756 rows x 2 columns]

# %%
df.loc[:,['city','result']]
# Out:
#               city  result
# 0        Hyderabad  normal
# 1             Pune  normal
# 2           Rajkot  normal
# 3           Indore  normal
# 4        Bangalore  normal
# ..             ...     ...
# 751         Mumbai  normal
# 752        Chennai  normal
# 753  Visakhapatnam  normal
# 754  Visakhapatnam  normal
# 755      Hyderabad  normal
#
# [756 rows x 2 columns]

# %%
df.loc[:,'Season':'date']
# Out:
#        Season           city        date
# 0    IPL-2017      Hyderabad  05-04-2017
# 1    IPL-2017           Pune  06-04-2017
# 2    IPL-2017         Rajkot  07-04-2017
# 3    IPL-2017         Indore  08-04-2017
# 4    IPL-2017      Bangalore  08-04-2017
# ..        ...            ...         ...
# 751  IPL-2019         Mumbai  05-05-2019
# 752  IPL-2019        Chennai  07-05-2019
# 753  IPL-2019  Visakhapatnam  08-05-2019
# 754  IPL-2019  Visakhapatnam  10-05-2019
# 755  IPL-2019      Hyderabad  12-05-2019
#
# [756 rows x 3 columns]

# %%
win = df.loc[:,['winner','Season','toss_winner']]
win[:2]
# Out:
#                    winner    Season                  toss_winner
# 0     Sunrisers Hyderabad  IPL-2017  Royal Challengers Bangalore
# 1  Rising Pune Supergiant  IPL-2017       Rising Pune Supergiant

# %%
win = df.loc[:,['winner','Season','toss_winner']]
win
# Out:
#                           winner    Season                  toss_winner
# 0            Sunrisers Hyderabad  IPL-2017  Royal Challengers Bangalore
# 1         Rising Pune Supergiant  IPL-2017       Rising Pune Supergiant
# 2          Kolkata Knight Riders  IPL-2017        Kolkata Knight Riders
# 3                Kings XI Punjab  IPL-2017              Kings XI Punjab
# 4    Royal Challengers Bangalore  IPL-2017  Royal Challengers Bangalore
# ..                           ...       ...                          ...
# 751               Mumbai Indians  IPL-2019               Mumbai Indians
# 752               Mumbai Indians  IPL-2019          Chennai Super Kings
# 753               Delhi Capitals  IPL-2019               Delhi Capitals
# 754          Chennai Super Kings  IPL-2019          Chennai Super Kings
# 755               Mumbai Indians  IPL-2019               Mumbai Indians
#
# [756 rows x 3 columns]

# %%
win[win.winner == win.toss_winner]
# Out:
#                           winner    Season                  toss_winner
# 1         Rising Pune Supergiant  IPL-2017       Rising Pune Supergiant
# 2          Kolkata Knight Riders  IPL-2017        Kolkata Knight Riders
# 3                Kings XI Punjab  IPL-2017              Kings XI Punjab
# 4    Royal Challengers Bangalore  IPL-2017  Royal Challengers Bangalore
# 5            Sunrisers Hyderabad  IPL-2017          Sunrisers Hyderabad
# ..                           ...       ...                          ...
# 750              Kings XI Punjab  IPL-2019              Kings XI Punjab
# 751               Mumbai Indians  IPL-2019               Mumbai Indians
# 753               Delhi Capitals  IPL-2019               Delhi Capitals
# 754          Chennai Super Kings  IPL-2019          Chennai Super Kings
# 755               Mumbai Indians  IPL-2019               Mumbai Indians
#
# [393 rows x 3 columns]

# %%
df
# Out:
#        Season           city        date                        team1  \
# 0    IPL-2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1    IPL-2017           Pune  06-04-2017               Mumbai Indians
# 2    IPL-2017         Rajkot  07-04-2017                Gujarat Lions
# 3    IPL-2017         Indore  08-04-2017       Rising Pune Supergiant
# 4    IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..        ...            ...         ...                          ...
# 751  IPL-2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  IPL-2019        Chennai  07-05-2019          Chennai Super Kings
# 753  IPL-2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  IPL-2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  IPL-2019      Hyderabad  12-05-2019               Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# ...

# %% [markdown]
# ### Fetch the data of Season 2017

# %%
df.Season.str.split('-',expand=True)
# Out:
#        0     1
# 0    IPL  2017
# 1    IPL  2017
# 2    IPL  2017
# 3    IPL  2017
# 4    IPL  2017
# ..   ...   ...
# 751  IPL  2019
# 752  IPL  2019
# 753  IPL  2019
# 754  IPL  2019
# 755  IPL  2019
#
# [756 rows x 2 columns]

# %%
df.Season.str.split('-',expand=True)[1]
# Out:
# 0      2017
# 1      2017
# 2      2017
# 3      2017
# 4      2017
#        ...
# 751    2019
# 752    2019
# 753    2019
# 754    2019
# 755    2019
# Name: 1, Length: 756, dtype: object

# %%
df.columns
# Out:
# Index(['Season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
df['year'] = df.Season.str.split('-',expand=True)[1]

# %%
df.columns
# Out:
# Index(['Season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3', 'year'],
#       dtype='object')

# %%
df.year[:3]
# Out:
# 0    2017
# 1    2017
# 2    2017
# Name: year, dtype: object

# %%
df[df.year ==  '2017']
# Out:
#       Season        city        date                        team1  \
# 0   IPL-2017   Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   IPL-2017        Pune  06-04-2017               Mumbai Indians
# 2   IPL-2017      Rajkot  07-04-2017                Gujarat Lions
# 3   IPL-2017      Indore  08-04-2017       Rising Pune Supergiant
# 4   IPL-2017   Bangalore  08-04-2017  Royal Challengers Bangalore
# 5   IPL-2017   Hyderabad  09-04-2017                Gujarat Lions
# 6   IPL-2017      Mumbai  09-04-2017        Kolkata Knight Riders
# 7   IPL-2017      Indore  10-04-2017  Royal Challengers Bangalore
# 8   IPL-2017        Pune  11-04-2017             Delhi Daredevils
# 9   IPL-2017      Mumbai  12-04-2017          Sunrisers Hyderabad
# 10  IPL-2017     Kolkata  13-04-2017              Kings XI Punjab
# 11  IPL-2017   Bangalore  14-04-2017  Royal Challengers Bangalore
# 12  IPL-2017      Rajkot  14-04-2017       Rising Pune Supergiant
# ...

# %%
m_17 = df[df.Season == 'IPL-2017']
m_17.head()
# Out:
#      Season       city        date                        team1  \
# 0  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1  IPL-2017       Pune  06-04-2017               Mumbai Indians
# 2  IPL-2017     Rajkot  07-04-2017                Gujarat Lions
# 3  IPL-2017     Indore  08-04-2017       Rising Pune Supergiant
# 4  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0          Sunrisers Hyderabad           35
# ...

# %% [markdown]
# ### how many matches played in season 2017

# %%
m_17.shape[0]
# Out:
# 59

# %%
len(m_17)
# Out:
# 59

# %% [markdown]
# ### give me the count of matches played in each city for 2017 season

# %%
m_17.city.value_counts()
# Out:
# Hyderabad     8
# Bangalore     8
# Mumbai        8
# Pune          7
# Kolkata       7
# Delhi         7
# Rajkot        5
# Chandigarh    4
# Indore        3
# Kanpur        2
# Name: city, dtype: int64

# %%
m_17.city.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### plot the citywise count using sns

# %%
sns.countplot(x='city',data=m_17)
plt.xticks(rotation=90);
# sort this countplot high to low

# %% [markdown]
# ### How many matches won by MI in s_2017

# %%
m_17[m_17.winner == 'Mumbai Indians']
# Out:
#       Season       city        date                        team1  \
# 6   IPL-2017     Mumbai  09-04-2017        Kolkata Knight Riders
# 9   IPL-2017     Mumbai  12-04-2017          Sunrisers Hyderabad
# 11  IPL-2017  Bangalore  14-04-2017  Royal Challengers Bangalore
# 15  IPL-2017     Mumbai  16-04-2017                Gujarat Lions
# 21  IPL-2017     Indore  20-04-2017              Kings XI Punjab
# 23  IPL-2017     Mumbai  22-04-2017               Mumbai Indians
# 33  IPL-2017     Rajkot  29-04-2017                Gujarat Lions
# 36  IPL-2017     Mumbai  01-05-2017  Royal Challengers Bangalore
# 43  IPL-2017      Delhi  06-05-2017               Mumbai Indians
# 52  IPL-2017    Kolkata  13-05-2017               Mumbai Indians
# 57  IPL-2017  Bangalore  19-05-2017        Kolkata Knight Riders
# 58  IPL-2017  Hyderabad  21-05-2017               Mumbai Indians
#
#                      team2                  toss_winner toss_decision  result  \
# ...

# %%
sum(m_17.winner == 'Mumbai Indians')
# Out:
# 12

# %% [markdown]
# ### How many matches played in season 2017

# %%
m_17.city.count()
# Out:
# 59

# %%
m_17.shape[0]
# Out:
# 59

# %%
len(m_17)
# Out:
# 59
